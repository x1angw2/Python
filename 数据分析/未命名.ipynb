# %%
import numpy as np

# %%
import matplotlib.pylab as plt

# %%
img_arr = plt.imread('hello.jpg')

# %%
plt.imshow(img_arr)

# %%
plt.imshow(img_arr - 50)

# %%
plt.imshow(img_arr)

# %%
plt.imshow(img_arr - 155)

# %%
import pandas as pd

# %%
from pandas import Series,DataFrame

# %%
Series(data=[11,22,33])
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %%
Series(data=[111,222,333],index=['a','b','c'])
# Out:
# a    111
# b    222
# c    333
# dtype: int64

# %%
arr = np.random.randint(0,100,size=(4,))

# %%
arr
# Out:
# array([97, 51, 28, 87])

# %%
s = Series(data = arr,index = ['a','b','c','d'])

# %%
s
# Out:
# a    97
# b    51
# c    28
# d    87
# dtype: int64

# %%
s[3]
# Out:
# 87

# %%
s['a']
# Out:
# 97

# %%
s['b':'d']
# Out:
# b    51
# c    28
# d    87
# dtype: int64

# %%
s.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-671cfa0cc2a0> in <module>
# ----> 1 s.values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
s.values
# Out:
# array([97, 51, 28, 87])

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s.isnull()
# Out:
# a    False
# b    False
# c    False
# d    False
# dtype: bool

# %%
s.notnull()
# Out:
# a    True
# b    True
# c    True
# d    True
# dtype: bool
